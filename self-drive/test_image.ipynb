# %%
from tensorflow.keras.models import load_model
from image_preprocess import Preprocess
import matplotlib.pyplot as plt

# %%
pr = Preprocess('path/here')

image = pr.readImg('13330.png')
image = pr.preprocess(image)

_, axes = plt.subplots(1, 1, figsize=(15, 15))

model = load_model('model_best.h5')

Y_pred = model.predict(image.reshape(1, 66, 200, 3))
print('predicted angle: ' + str(Y_pred[0][0]))
axes.imshow(image)
# Out:
# predicted angle: 0.07740983
